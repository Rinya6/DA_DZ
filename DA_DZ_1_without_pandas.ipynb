# %%
import csv
import sys
csv.field_size_limit(sys.maxsize)

# %%
import csv
import sys
csv.field_size_limit(100000000)
# Out:
# 131072

# %%
vak = list(csv.DictReader(open('Vacancy.csv', encoding='utf-8', newline='')))

# %%
vak[0]
# Out:
# OrderedDict([('id', '383479'),
#              ('created_at', '2021-03-14 09:39:21.854462'),
#              ('updated_at', '2021-03-14 09:39:21.854584'),
#              ('vacid', '1474941'),
#              ('vactitle', 'Senior java-разработчик (в команду Онбординга)'),
#              ('vacdescription',
# ...

# %%
#выборка по строке 'vactitle' - вакансии 
vak1 = { row['vactitle'] for row in vak}

# %%
#сколько всего вакансий выгружено
len(vak1)
# Out:
# 2167

# %%
#вывод списка вакансий 
vak1
# Out:
# {'Team Lead QA',
#  'Разработчик IBSO',
#  'Android разработчик (Sber911)',
#  'Enterprise Aрхитектор',
#  'Консультант «SAP Solution Manager»',
#  'Строительный эксперт',
#  'SRE (Openshift / Kubernetes)',
#  'Руководитель направления',
#  'Ведущий инженер информационной безопасности',
#  'Администратор тестовых сред',
#  'DevOps',
#  'Рекрутер Executive',
#  'Техническая заявка для SberDevices для Диалог',
#  'Старший инженер по кибербезопасности',
#  'Старший специалист сектора недвижимости',
#  'Эксперт по автоматизации тестирования',
#  'Senior Java-разработчик (АС КЮЛ ППРБ)',
#  'Специалист отдела досудебного взыскания задолженности',
#  'Архитектор Фабрики Данных (Руководитель направления)',
#  'Слесарь-сборщик (направление беспилотники)',
#  'Product owner|развитие сервиса межкорпоративного ЭДО в интернет банке СберБизнес',
#  'Java-разработчик (Хранилище данных)',
#  'Java developer (middle)',
#  'Data Analyst в команду «Отчетность и аналитика»',
# ...

# %%
# Сколько вакансий, которые вам нравятся?
vak3= [x for x in vak1 if x.lower().find('руководитель направления')>-1]
vak3
# Out:
# ['Руководитель направления',
#  'Архитектор Фабрики Данных (Руководитель направления)',
#  'Руководитель направления в команду «Коммуникации», дивизион «Особенные решения»',
#  'Руководитель направления (Защита облачной инфраструктуры)',
#  'Руководитель направления (стресс-тестирование, риск-аппетит, портфельные лимиты)',
#  'Руководитель направления "ассистент для сотрудников Сбера и компаний его экосистемы"',
#  'Руководитель направления продаж продуктов торгового финансирования',
#  'Руководитель направления (Продвижение культуры управления клиентским опытом)',
#  'Руководитель направления СББОЛ/Отдел Java разработки/, (Центральный офис Москва)',
#  'Руководитель направления контроля качества',
#  'Руководитель направления (Риски)',
#  'Руководитель направления в Проектный офис Операционного центра',
#  'Руководитель направления методологии (Кибербезопасность)',
#  'Руководитель направления по оптимизации очередей в Контакт-центре',
#  'Руководитель направления разработки',
# ...

# %%
len(vak3)
# Out:
# 66

# %%
# Насколько свежие эти вакансии?
-не знаю(

# %%
# Сколько вакансий с позициями на которых вы работаете?
zr = 'заместитель руководителя'.find('заместитель')
zr
# Out:
# 0

# %%
# Сколько вакансий для аналатика данных?
vak2= [x for x in vak1 if x.lower().find('analyst')>-1]
vak2
# Out:
# ['Data Analyst в команду «Отчетность и аналитика»',
#  'Data Analyst',
#  'Data Analyst Дивизион `Массовая персонализация`',
#  'Стажер Data engineer/Data analyst',
#  'Data analyst (в Лабораторию клиентского опыта)',
#  'Data Analyst ("Корпоративные клиенты 360")',
#  'Senior Data analyst (блок УБ, команда инвестиционных продуктов)',
#  'Risk Quant (Quantitative Analyst)',
#  'Analyst / Associate в Change подразделении Департамента Инвестиционной деятельности',
#  'Lead Data Analyst',
#  'Analyst International project in the UAE',
#  'Системный аналитик/IT analyst',
#  'Руководитель направления по аналитике данных в команду CLTV. Senior data analyst',
#  'Data Analyst Дивизион "Особенные решения"',
#  'Data analyst. Стажера - Аналитик (кластер Персональные предложения)',
#  'Data analyst (внедрение моделей)',
#  'Senior data analyst. Дивизион `Лояльность`',
#  'Data analyst (Python)',
#  'Аналитик / data analyst. Дивизион `Лояльность`',
# ...

# %%
len(vak2)
# Out:
# 26

# %%
# Сколько вакансий для аналитика данных с использованием Python?
vakP = [x for x in vak2 if x.lower().find('python')>-1]
vakP
# Out:
# ['Data analyst (Python)']

# %%
len(vakP)
# Out:
# 1
